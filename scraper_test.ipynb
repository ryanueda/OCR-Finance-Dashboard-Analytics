# %%
import camelot
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os

# %%
tables = camelot.read_pdf('statements/statement_3.pdf', flavor='stream', pages='all')
print(tables[0])
# Out:
# c:\Users\rutsm\anaconda3\envs\dele_env\lib\site-packages\camelot\parsers\stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# <Table shape=(8, 1)>
# c:\Users\rutsm\anaconda3\envs\dele_env\lib\site-packages\camelot\parsers\stream.py:365: UserWarning: No tables found in table area 2
#   warnings.warn(f"No tables found in table area {table_idx + 1}")

# %%
tables[1].df
# Out:
#                     0                                   1               2  \
# 0            Deposits
# 1   ePOSBkids Account
# 2                Date                         Description  Withdrawal (-)
# 3                                 Balance Brought Forward
# 4          31/12/2022              FAST Payment / Receipt            8.00
# 5                                         PAYNOW TRANSFER
# 6                                            TO: ASON ANG
# 7                                         PAYNOW TRANSFER
# 8                                                   OTHER
# 9          02/01/2023                      Funds Transfer
# 10                                  009-1-024105 : I-BANK
# 11         02/01/2023                      Funds Transfer
# 12                                  126-17874-3  : I-BANK
# 13         02/01/2023              FAST Payment / Receipt
# 14                            INCOMING PAYNOW REF 7101410
# 15                            FROM: KLAUDINE SHANNON QUEK
# ...
